# %% [markdown]
# ## Credit Card Payment Default Prediction With Leras [Deep Learning]

# %% [markdown]
# ### dataset is downloaded from UCI Machine Learning Repository, with default payment in Taiwan
# ### We focus on last column [default payment next month]. A value of 1 means a default occurred

# %%
import pandas as pd
df=pd.read_csv('default.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
#  13  BILL_AMT3                   30000 non-null  int64
#  14  BILL_AMT4                   30000 non-null  int64
#  15  BILL_AMT5                   30000 non-null  int64
#  16  BILL_AMT6                   30000 non-null  int64
#  17  PAY_AMT1                    30000 non-null  int64
#  18  PAY_AMT2                    30000 non-null  int64
#  19  PAY_AMT3                    30000 non-null  int64
#  20  PAY_AMT4                    30000 non-null  int64
#  21  PAY_AMT5                    30000 non-null  int64
#  22  PAY_AMT6                    30000 non-null  int64
#  23  default payment next month  30000 non-null  int64
# dtypes: int64(24)
# memory usage: 5.5 MB

# %%
# split and scale the data
feature_columns=df.columns[:-1]
features=df.loc[:,feature_columns]
target=df.loc[:,'default payment next month']

# %%
# split into training and testing datasets
from sklearn.model_selection import train_test_split
train_features,test_features,train_target,test_target=train_test_split(features,target,test_size=0.2,random_state=0)
# test_size=0.2 means we include 20% of inputs in test split
import numpy as np
train_x,train_y=np.array(train_features),np.array(train_target)
test_x,test_y=np.array(test_features),np.array(test_target)

# %%
# standardize the dataset by scaling the features
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
train_scaled_x=scaler.fit_transform(train_x)
test_scaled_x=scaler.transform(test_x)

# %% [markdown]
# ### Design a Deep Neural Network with Five Hidden Layers using Keras

# %%
# create a sequential model
# add layers, here we use ReLU activation 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization

num_features = train_scaled_x.shape[1]

model = Sequential()
model.add(Dense(80, input_dim=num_features, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(80, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(40, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 80)                1920
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 80)                6480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                3240
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 11,841
# Trainable params: 11,761
# Non-trainable params: 80
# _________________________________________________________________

# %%
# using Adam Optimizer, producing accuracy metrix
import tensorflow as tf
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

# %%
# train the model
from keras.callbacks import History
callback_history=History()
model.fit(train_scaled_x,train_y,validation_split=0.2,epochs=100,callbacks=[callback_history])
# Out:
# Epoch 1/100
# 600/600 [==============================] - 2s 2ms/step - loss: 0.5590 - accuracy: 0.7316 - val_loss: 0.4792 - val_accuracy: 0.7898
# Epoch 2/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4749 - accuracy: 0.8041 - val_loss: 0.4893 - val_accuracy: 0.7896
# Epoch 3/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4573 - accuracy: 0.8113 - val_loss: 0.4661 - val_accuracy: 0.8017
# Epoch 4/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4564 - accuracy: 0.8077 - val_loss: 0.4552 - val_accuracy: 0.8083
# Epoch 5/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4581 - accuracy: 0.8073 - val_loss: 0.4529 - val_accuracy: 0.8115
# Epoch 6/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4582 - accuracy: 0.8063 - val_loss: 0.4579 - val_accuracy: 0.8119
# Epoch 7/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4437 - accuracy: 0.8187 - val_loss: 0.4483 - val_accuracy: 0.8150
# Epoch 8/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4468 - accuracy: 0.8131 - val_loss: 0.4497 - val_accuracy: 0.8110
# Epoch 9/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4451 - accuracy: 0.8113 - val_loss: 0.4513 - val_accuracy: 0.8081
# Epoch 10/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4424 - accuracy: 0.8148 - val_loss: 0.4475 - val_accuracy: 0.8144
# Epoch 11/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4397 - accuracy: 0.8189 - val_loss: 0.4460 - val_accuracy: 0.8125
# Epoch 12/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4512 - accuracy: 0.8094 - val_loss: 0.4447 - val_accuracy: 0.8152
# Epoch 13/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4367 - accuracy: 0.8189 - val_loss: 0.4520 - val_accuracy: 0.8058
# Epoch 14/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4476 - accuracy: 0.8095 - val_loss: 0.4488 - val_accuracy: 0.8133
# Epoch 15/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4401 - accuracy: 0.8161 - val_loss: 0.4460 - val_accuracy: 0.8127
# Epoch 16/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4344 - accuracy: 0.8208 - val_loss: 0.4468 - val_accuracy: 0.8135
# Epoch 17/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4336 - accuracy: 0.8194 - val_loss: 0.4498 - val_accuracy: 0.8110
# Epoch 18/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4372 - accuracy: 0.8180 - val_loss: 0.4446 - val_accuracy: 0.8131
# Epoch 19/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4412 - accuracy: 0.8150 - val_loss: 0.4425 - val_accuracy: 0.8148
# Epoch 20/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4400 - accuracy: 0.8151 - val_loss: 0.4428 - val_accuracy: 0.8156
# Epoch 21/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.8171 - val_loss: 0.4489 - val_accuracy: 0.8146
# Epoch 22/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4411 - accuracy: 0.8146 - val_loss: 0.4470 - val_accuracy: 0.8125
# Epoch 23/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4315 - accuracy: 0.8216 - val_loss: 0.4483 - val_accuracy: 0.8142
# Epoch 24/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4325 - accuracy: 0.8169 - val_loss: 0.4418 - val_accuracy: 0.8123
# Epoch 25/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4327 - accuracy: 0.8173 - val_loss: 0.4431 - val_accuracy: 0.8121
# Epoch 26/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4315 - accuracy: 0.8225 - val_loss: 0.4421 - val_accuracy: 0.8135
# Epoch 27/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4333 - accuracy: 0.8187 - val_loss: 0.4432 - val_accuracy: 0.8125
# Epoch 28/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4341 - accuracy: 0.8194 - val_loss: 0.4456 - val_accuracy: 0.8142
# Epoch 29/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4363 - accuracy: 0.8197 - val_loss: 0.4422 - val_accuracy: 0.8140
# Epoch 30/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8255 - val_loss: 0.4410 - val_accuracy: 0.8146
# Epoch 31/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4342 - accuracy: 0.8159 - val_loss: 0.4399 - val_accuracy: 0.8152
# Epoch 32/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4375 - accuracy: 0.8195 - val_loss: 0.4430 - val_accuracy: 0.8144
# Epoch 33/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4227 - accuracy: 0.8235 - val_loss: 0.4407 - val_accuracy: 0.8160
# Epoch 34/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4283 - accuracy: 0.8181 - val_loss: 0.4395 - val_accuracy: 0.8160
# Epoch 35/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4288 - accuracy: 0.8212 - val_loss: 0.4382 - val_accuracy: 0.8148
# Epoch 36/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4233 - accuracy: 0.8246 - val_loss: 0.4421 - val_accuracy: 0.8163
# Epoch 37/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4304 - accuracy: 0.8204 - val_loss: 0.4424 - val_accuracy: 0.8129
# Epoch 38/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4282 - accuracy: 0.8218 - val_loss: 0.4423 - val_accuracy: 0.8133
# Epoch 39/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4340 - accuracy: 0.8204 - val_loss: 0.4428 - val_accuracy: 0.8112
# Epoch 40/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4349 - accuracy: 0.8175 - val_loss: 0.4477 - val_accuracy: 0.8135
# Epoch 41/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4286 - accuracy: 0.8180 - val_loss: 0.4422 - val_accuracy: 0.8154
# Epoch 42/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4256 - accuracy: 0.8206 - val_loss: 0.4424 - val_accuracy: 0.8140
# Epoch 43/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4396 - accuracy: 0.8134 - val_loss: 0.4429 - val_accuracy: 0.8127
# Epoch 44/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4351 - accuracy: 0.8156 - val_loss: 0.4446 - val_accuracy: 0.8133
# Epoch 45/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4263 - accuracy: 0.8221 - val_loss: 0.4418 - val_accuracy: 0.8146
# Epoch 46/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4319 - accuracy: 0.8177 - val_loss: 0.4440 - val_accuracy: 0.8150
# Epoch 47/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4363 - accuracy: 0.8145 - val_loss: 0.4387 - val_accuracy: 0.8129
# Epoch 48/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4369 - accuracy: 0.8119 - val_loss: 0.4448 - val_accuracy: 0.8138
# Epoch 49/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.8248 - val_loss: 0.4429 - val_accuracy: 0.8152
# Epoch 50/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4350 - accuracy: 0.8157 - val_loss: 0.4379 - val_accuracy: 0.8154
# Epoch 51/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.8234 - val_loss: 0.4423 - val_accuracy: 0.8127
# Epoch 52/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4323 - accuracy: 0.8191 - val_loss: 0.4442 - val_accuracy: 0.8144
# Epoch 53/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4348 - accuracy: 0.8155 - val_loss: 0.4427 - val_accuracy: 0.8150
# Epoch 54/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4290 - accuracy: 0.8196 - val_loss: 0.4409 - val_accuracy: 0.8119
# Epoch 55/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4293 - accuracy: 0.8227 - val_loss: 0.4395 - val_accuracy: 0.8146
# Epoch 56/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4255 - accuracy: 0.8244 - val_loss: 0.4444 - val_accuracy: 0.8154
# Epoch 57/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4294 - accuracy: 0.8174 - val_loss: 0.4441 - val_accuracy: 0.8150
# Epoch 58/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.8224 - val_loss: 0.4441 - val_accuracy: 0.8133
# Epoch 59/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4279 - accuracy: 0.8176 - val_loss: 0.4421 - val_accuracy: 0.8129
# Epoch 60/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4210 - accuracy: 0.8236 - val_loss: 0.4396 - val_accuracy: 0.8165
# Epoch 61/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4187 - accuracy: 0.8269 - val_loss: 0.4425 - val_accuracy: 0.8144
# Epoch 62/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4350 - accuracy: 0.8176 - val_loss: 0.4418 - val_accuracy: 0.8125
# Epoch 63/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4281 - accuracy: 0.8211 - val_loss: 0.4402 - val_accuracy: 0.8135
# Epoch 64/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4342 - accuracy: 0.8187 - val_loss: 0.4428 - val_accuracy: 0.8127
# Epoch 65/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4262 - accuracy: 0.8191 - val_loss: 0.4411 - val_accuracy: 0.8173
# Epoch 66/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4243 - accuracy: 0.8209 - val_loss: 0.4437 - val_accuracy: 0.8148
# Epoch 67/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4220 - accuracy: 0.8247 - val_loss: 0.4468 - val_accuracy: 0.8146
# Epoch 68/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4307 - accuracy: 0.8180 - val_loss: 0.4430 - val_accuracy: 0.8138
# Epoch 69/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4206 - accuracy: 0.8221 - val_loss: 0.4422 - val_accuracy: 0.8135
# Epoch 70/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4256 - accuracy: 0.8237 - val_loss: 0.4428 - val_accuracy: 0.8140
# Epoch 71/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4211 - accuracy: 0.8262 - val_loss: 0.4436 - val_accuracy: 0.8125
# Epoch 72/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4224 - accuracy: 0.8218 - val_loss: 0.4424 - val_accuracy: 0.8140
# Epoch 73/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4295 - accuracy: 0.8195 - val_loss: 0.4449 - val_accuracy: 0.8138
# Epoch 74/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.8229 - val_loss: 0.4422 - val_accuracy: 0.8154
# Epoch 75/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4256 - accuracy: 0.8226 - val_loss: 0.4451 - val_accuracy: 0.8129
# Epoch 76/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4232 - accuracy: 0.8236 - val_loss: 0.4422 - val_accuracy: 0.8163
# Epoch 77/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.8255 - val_loss: 0.4442 - val_accuracy: 0.8140
# Epoch 78/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4253 - accuracy: 0.8245 - val_loss: 0.4405 - val_accuracy: 0.8144
# Epoch 79/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.8230 - val_loss: 0.4407 - val_accuracy: 0.8140
# Epoch 80/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4196 - accuracy: 0.8233 - val_loss: 0.4419 - val_accuracy: 0.8135
# Epoch 81/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4200 - accuracy: 0.8256 - val_loss: 0.4430 - val_accuracy: 0.8142
# Epoch 82/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4189 - accuracy: 0.8243 - val_loss: 0.4418 - val_accuracy: 0.8125
# Epoch 83/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4298 - accuracy: 0.8179 - val_loss: 0.4472 - val_accuracy: 0.8123
# Epoch 84/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4160 - accuracy: 0.8295 - val_loss: 0.4417 - val_accuracy: 0.8133
# Epoch 85/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4251 - accuracy: 0.8211 - val_loss: 0.4419 - val_accuracy: 0.8133
# Epoch 86/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4248 - accuracy: 0.8195 - val_loss: 0.4473 - val_accuracy: 0.8121
# Epoch 87/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4200 - accuracy: 0.8214 - val_loss: 0.4450 - val_accuracy: 0.8146
# Epoch 88/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.8221 - val_loss: 0.4457 - val_accuracy: 0.8152
# Epoch 89/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4209 - accuracy: 0.8227 - val_loss: 0.4426 - val_accuracy: 0.8144
# Epoch 90/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4209 - accuracy: 0.8207 - val_loss: 0.4441 - val_accuracy: 0.8131
# Epoch 91/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4266 - accuracy: 0.8234 - val_loss: 0.4436 - val_accuracy: 0.8117
# Epoch 92/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4209 - accuracy: 0.8226 - val_loss: 0.4447 - val_accuracy: 0.8131
# Epoch 93/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4204 - accuracy: 0.8217 - val_loss: 0.4442 - val_accuracy: 0.8127
# Epoch 94/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4190 - accuracy: 0.8257 - val_loss: 0.4477 - val_accuracy: 0.8112
# Epoch 95/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.8213 - val_loss: 0.4482 - val_accuracy: 0.8112
# Epoch 96/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4287 - accuracy: 0.8199 - val_loss: 0.4425 - val_accuracy: 0.8148
# Epoch 97/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.8239 - val_loss: 0.4465 - val_accuracy: 0.8140
# Epoch 98/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4206 - accuracy: 0.8226 - val_loss: 0.4468 - val_accuracy: 0.8140
# Epoch 99/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8223 - val_loss: 0.4443 - val_accuracy: 0.8108
# Epoch 100/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4211 - accuracy: 0.8232 - val_loss: 0.4446 - val_accuracy: 0.8142

# %% [markdown]
# ### Measuring the Performance with Risk Metrics

# %%
# loss and accuracy
test_loss,test_acc=model.evaluate(test_scaled_x,test_y)
print('Test loss:',test_loss)
print('Test accuracy',test_acc)
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4289 - accuracy: 0.8247
# Test loss: 0.42891252040863037
# Test accuracy 0.8246666789054871

# %%
# round data to the nearest 0 or 1 to obtain the binary classification label
predictions=model.predict(test_scaled_x)
pred_values=predictions.round().ravel()

# %%
# plot confusion matrix
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(test_y,pred_values)
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
flags=['No','Yes']
plt.subplots(figsize=(12,8))
sns.heatmap(matrix.T,square=True,annot=True,fmt='g',cbar=True,cmap=plt.cm.Blues,xticklabels=flags,yticklabels=flags)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Credit card payment default prediction')
# Out:
# Text(0.5, 1.0, 'Credit card payment default prediction')

# %%
# display multiple risk matrix
from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score)
actual,predicted=test_y,pred_values
print('accuracy_score:',accuracy_score(actual,predicted))
print('precision_score:',precision_score(actual,predicted))
print('recall score:',recall_score(actual,predicted))
print('f1 score:',f1_score(actual,predicted))
# Out:
# accuracy_score: 0.8246666666666667
# precision_score: 0.6689655172413793
# recall score: 0.37393986121819583
# f1 score: 0.4797230464886251

# %%
# the low recall score and slightly below0average F1 score suggest that the model is not competitative
# so we need to visit historical metrics

# %% [markdown]
# ### Displaying Recorded Events in Keras History

# %%
train_acc = callback_history.history['accuracy']
val_acc = callback_history.history['val_accuracy']
train_loss = callback_history.history['loss']
val_loss = callback_history.history['val_loss']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
epochs=range(1,len(train_acc)+1)

plt.figure(figsize=(12,8))
plt.plot(epochs,train_loss,label='Training')
plt.plot(epochs,val_loss,'--',label='Validation')
plt.title('Training and Validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend();

# %%
# the solid line shows the the training loss decreases as epoches increase, meaning the model learns data better over time

# %%
# the dashed line shows the validation loss increases as epoches increase, meaning the model is not generalized well on validation set

# %%
# these trend suggests an overfitting

# %% [markdown]
# ### Plot the Training and Validation Accuracy

# %%
plt.figure(figsize=(12,8))
plt.plot(epochs,train_acc,'-',label='Training')
plt.plot(epochs,val_acc,'--',label='Validation')
plt.title('Training and Validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend();

# %%
# the solid line suggests training accuracy increases as epoches increase
# the dashed line suggests validation accuracy decreasing
# These suggests an overfitting
# to fix it, we may use more training data, reduce capacity of network, add weight regularization or use a fropout layer
